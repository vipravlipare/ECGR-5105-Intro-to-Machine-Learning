# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import datasets, transforms
import time

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

data_path = "../data-unversioned/p1ch7"
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.4914, 0.4823, 0.4468),
                         (0.2470, 0.2435, 0.2616))
])

cifar10_train = datasets.CIFAR10(data_path, train=True, download=True, transform=transform)
cifar10_test  = datasets.CIFAR10(data_path, train=False, download=True, transform=transform)

cifar10_trainX = torch.stack([img.view(-1) for img, _ in cifar10_train])
cifar10_trainY = torch.tensor([label for _, label in cifar10_train], dtype=torch.long)

cifar10_testX = torch.stack([img.view(-1) for img, _ in cifar10_test])
cifar10_testY = torch.tensor([label for _, label in cifar10_test], dtype=torch.long)

cifar10_trainX = cifar10_trainX.to(device)
cifar10_trainY = cifar10_trainY.to(device)
cifar10_testX  = cifar10_testX.to(device)
cifar10_testY  = cifar10_testY.to(device)

train_dataset = torch.utils.data.TensorDataset(cifar10_trainX, cifar10_trainY)
val_dataset   = torch.utils.data.TensorDataset(cifar10_testX, cifar10_testY)

train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=64, shuffle=True)
val_loader   = torch.utils.data.DataLoader(val_dataset, batch_size=1000, shuffle=False)

# %%
input_size = 3 * 32 * 32
model = nn.Sequential(
    nn.Linear(input_size, 512),
    nn.Tanh(),
    nn.Linear(512, 10),
    nn.LogSoftmax(dim=1)
).to(device)

learning_rate = 1e-3
optimizer = optim.SGD(model.parameters(), lr=learning_rate)
loss_fn = nn.NLLLoss()

n_epochs = 300
start = time.time()

for epoch in range(n_epochs):
    model.train()
    running_loss = 0.0
    for batch_X, batch_Y in train_loader:
        outputs = model(batch_X)
        loss = loss_fn(outputs, batch_Y)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        running_loss += loss.item() * batch_X.size(0)

    epoch_loss = running_loss / len(train_loader.dataset)
    print(f"Epoch {epoch+1}, Loss: {epoch_loss:.4f}")

end = time.time()
print("\nTraining Time =", end - start, "seconds")
print("Final Training Loss =", epoch_loss)

model.eval()
correct = 0
total = 0
with torch.no_grad():
    for batch_X, batch_Y in val_loader:
        outputs = model(batch_X)
        preds = outputs.argmax(dim=1)
        correct += (preds == batch_Y).sum().item()
        total += batch_Y.size(0)

accuracy = correct / total
print("Evaluation Accuracy =", accuracy)
# Out:
# Epoch 1, Loss: 2.0014
# Epoch 2, Loss: 1.8677
# Epoch 3, Loss: 1.8215
# Epoch 4, Loss: 1.7933
# Epoch 5, Loss: 1.7729
# Epoch 6, Loss: 1.7563
# Epoch 7, Loss: 1.7422
# Epoch 8, Loss: 1.7298
# Epoch 9, Loss: 1.7185
# Epoch 10, Loss: 1.7078
# Epoch 11, Loss: 1.6981
# Epoch 12, Loss: 1.6885
# Epoch 13, Loss: 1.6801
# Epoch 14, Loss: 1.6718
# Epoch 15, Loss: 1.6640
# Epoch 16, Loss: 1.6565
# Epoch 17, Loss: 1.6494
# Epoch 18, Loss: 1.6425
# Epoch 19, Loss: 1.6356
# Epoch 20, Loss: 1.6295
# Epoch 21, Loss: 1.6230
# Epoch 22, Loss: 1.6170
# Epoch 23, Loss: 1.6110
# Epoch 24, Loss: 1.6052
# Epoch 25, Loss: 1.5996
# Epoch 26, Loss: 1.5939
# Epoch 27, Loss: 1.5884
# Epoch 28, Loss: 1.5833
# Epoch 29, Loss: 1.5778
# Epoch 30, Loss: 1.5726
# Epoch 31, Loss: 1.5673
# Epoch 32, Loss: 1.5622
# Epoch 33, Loss: 1.5571
# Epoch 34, Loss: 1.5522
# Epoch 35, Loss: 1.5472
# Epoch 36, Loss: 1.5422
# Epoch 37, Loss: 1.5374
# Epoch 38, Loss: 1.5324
# Epoch 39, Loss: 1.5276
# Epoch 40, Loss: 1.5225
# Epoch 41, Loss: 1.5180
# Epoch 42, Loss: 1.5131
# Epoch 43, Loss: 1.5083
# Epoch 44, Loss: 1.5037
# Epoch 45, Loss: 1.4989
# Epoch 46, Loss: 1.4941
# Epoch 47, Loss: 1.4896
# Epoch 48, Loss: 1.4847
# Epoch 49, Loss: 1.4801
# Epoch 50, Loss: 1.4753
# Epoch 51, Loss: 1.4708
# Epoch 52, Loss: 1.4658
# Epoch 53, Loss: 1.4614
# Epoch 54, Loss: 1.4566
# Epoch 55, Loss: 1.4521
# Epoch 56, Loss: 1.4470
# Epoch 57, Loss: 1.4426
# Epoch 58, Loss: 1.4381
# Epoch 59, Loss: 1.4335
# Epoch 60, Loss: 1.4286
# Epoch 61, Loss: 1.4243
# Epoch 62, Loss: 1.4195
# Epoch 63, Loss: 1.4151
# Epoch 64, Loss: 1.4103
# Epoch 65, Loss: 1.4060
# Epoch 66, Loss: 1.4014
# Epoch 67, Loss: 1.3967
# Epoch 68, Loss: 1.3922
# Epoch 69, Loss: 1.3876
# Epoch 70, Loss: 1.3832
# Epoch 71, Loss: 1.3783
# Epoch 72, Loss: 1.3741
# Epoch 73, Loss: 1.3696
# Epoch 74, Loss: 1.3656
# Epoch 75, Loss: 1.3606
# Epoch 76, Loss: 1.3563
# Epoch 77, Loss: 1.3521
# Epoch 78, Loss: 1.3476
# Epoch 79, Loss: 1.3428
# Epoch 80, Loss: 1.3384
# Epoch 81, Loss: 1.3342
# Epoch 82, Loss: 1.3294
# Epoch 83, Loss: 1.3249
# Epoch 84, Loss: 1.3207
# Epoch 85, Loss: 1.3163
# Epoch 86, Loss: 1.3118
# Epoch 87, Loss: 1.3075
# Epoch 88, Loss: 1.3029
# Epoch 89, Loss: 1.2986
# Epoch 90, Loss: 1.2940
# Epoch 91, Loss: 1.2898
# Epoch 92, Loss: 1.2855
# Epoch 93, Loss: 1.2808
# Epoch 94, Loss: 1.2765
# Epoch 95, Loss: 1.2721
# Epoch 96, Loss: 1.2674
# Epoch 97, Loss: 1.2633
# Epoch 98, Loss: 1.2588
# Epoch 99, Loss: 1.2547
# Epoch 100, Loss: 1.2503
# Epoch 101, Loss: 1.2458
# Epoch 102, Loss: 1.2416
# Epoch 103, Loss: 1.2370
# Epoch 104, Loss: 1.2325
# Epoch 105, Loss: 1.2281
# Epoch 106, Loss: 1.2236
# Epoch 107, Loss: 1.2194
# Epoch 108, Loss: 1.2149
# Epoch 109, Loss: 1.2107
# Epoch 110, Loss: 1.2063
# Epoch 111, Loss: 1.2020
# Epoch 112, Loss: 1.1973
# Epoch 113, Loss: 1.1932
# Epoch 114, Loss: 1.1889
# Epoch 115, Loss: 1.1847
# Epoch 116, Loss: 1.1799
# Epoch 117, Loss: 1.1756
# Epoch 118, Loss: 1.1715
# Epoch 119, Loss: 1.1669
# Epoch 120, Loss: 1.1626
# Epoch 121, Loss: 1.1585
# Epoch 122, Loss: 1.1539
# Epoch 123, Loss: 1.1498
# Epoch 124, Loss: 1.1453
# Epoch 125, Loss: 1.1408
# Epoch 126, Loss: 1.1369
# Epoch 127, Loss: 1.1322
# Epoch 128, Loss: 1.1280
# Epoch 129, Loss: 1.1236
# Epoch 130, Loss: 1.1194
# Epoch 131, Loss: 1.1148
# Epoch 132, Loss: 1.1109
# Epoch 133, Loss: 1.1063
# Epoch 134, Loss: 1.1020
# Epoch 135, Loss: 1.0978
# Epoch 136, Loss: 1.0936
# Epoch 137, Loss: 1.0893
# Epoch 138, Loss: 1.0848
# Epoch 139, Loss: 1.0804
# Epoch 140, Loss: 1.0765
# Epoch 141, Loss: 1.0717
# Epoch 142, Loss: 1.0679
# Epoch 143, Loss: 1.0636
# Epoch 144, Loss: 1.0593
# Epoch 145, Loss: 1.0550
# Epoch 146, Loss: 1.0509
# Epoch 147, Loss: 1.0463
# Epoch 148, Loss: 1.0420
# Epoch 149, Loss: 1.0380
# Epoch 150, Loss: 1.0334
# Epoch 151, Loss: 1.0296
# Epoch 152, Loss: 1.0253
# Epoch 153, Loss: 1.0208
# Epoch 154, Loss: 1.0166
# Epoch 155, Loss: 1.0124
# Epoch 156, Loss: 1.0084
# Epoch 157, Loss: 1.0039
# Epoch 158, Loss: 1.0001
# Epoch 159, Loss: 0.9956
# Epoch 160, Loss: 0.9915
# Epoch 161, Loss: 0.9870
# Epoch 162, Loss: 0.9829
# Epoch 163, Loss: 0.9789
# Epoch 164, Loss: 0.9749
# Epoch 165, Loss: 0.9705
# Epoch 166, Loss: 0.9664
# Epoch 167, Loss: 0.9621
# Epoch 168, Loss: 0.9581
# Epoch 169, Loss: 0.9539
# Epoch 170, Loss: 0.9497
# Epoch 171, Loss: 0.9457
# Epoch 172, Loss: 0.9416
# Epoch 173, Loss: 0.9373
# Epoch 174, Loss: 0.9331
# Epoch 175, Loss: 0.9293
# Epoch 176, Loss: 0.9252
# Epoch 177, Loss: 0.9211
# Epoch 178, Loss: 0.9168
# Epoch 179, Loss: 0.9131
# Epoch 180, Loss: 0.9089
# Epoch 181, Loss: 0.9049
# Epoch 182, Loss: 0.9007
# Epoch 183, Loss: 0.8965
# Epoch 184, Loss: 0.8930
# Epoch 185, Loss: 0.8887
# Epoch 186, Loss: 0.8848
# Epoch 187, Loss: 0.8807
# Epoch 188, Loss: 0.8765
# Epoch 189, Loss: 0.8726
# Epoch 190, Loss: 0.8684
# Epoch 191, Loss: 0.8647
# Epoch 192, Loss: 0.8610
# Epoch 193, Loss: 0.8564
# Epoch 194, Loss: 0.8526
# Epoch 195, Loss: 0.8489
# Epoch 196, Loss: 0.8450
# Epoch 197, Loss: 0.8411
# Epoch 198, Loss: 0.8372
# Epoch 199, Loss: 0.8333
# Epoch 200, Loss: 0.8292
# Epoch 201, Loss: 0.8256
# Epoch 202, Loss: 0.8218
# Epoch 203, Loss: 0.8179
# Epoch 204, Loss: 0.8143
# Epoch 205, Loss: 0.8099
# Epoch 206, Loss: 0.8063
# Epoch 207, Loss: 0.8024
# Epoch 208, Loss: 0.7985
# Epoch 209, Loss: 0.7947
# Epoch 210, Loss: 0.7907
# Epoch 211, Loss: 0.7872
# Epoch 212, Loss: 0.7838
# Epoch 213, Loss: 0.7795
# Epoch 214, Loss: 0.7760
# Epoch 215, Loss: 0.7722
# Epoch 216, Loss: 0.7683
# Epoch 217, Loss: 0.7646
# Epoch 218, Loss: 0.7609
# Epoch 219, Loss: 0.7573
# Epoch 220, Loss: 0.7534
# Epoch 221, Loss: 0.7499
# Epoch 222, Loss: 0.7463
# Epoch 223, Loss: 0.7426
# Epoch 224, Loss: 0.7390
# Epoch 225, Loss: 0.7354
# Epoch 226, Loss: 0.7313
# Epoch 227, Loss: 0.7282
# Epoch 228, Loss: 0.7248
# Epoch 229, Loss: 0.7210
# Epoch 230, Loss: 0.7173
# Epoch 231, Loss: 0.7139
# Epoch 232, Loss: 0.7101
# Epoch 233, Loss: 0.7067
# Epoch 234, Loss: 0.7031
# Epoch 235, Loss: 0.6995
# Epoch 236, Loss: 0.6961
# Epoch 237, Loss: 0.6925
# Epoch 238, Loss: 0.6891
# Epoch 239, Loss: 0.6854
# Epoch 240, Loss: 0.6822
# Epoch 241, Loss: 0.6787
# Epoch 242, Loss: 0.6750
# Epoch 243, Loss: 0.6716
# Epoch 244, Loss: 0.6686
# Epoch 245, Loss: 0.6651
# Epoch 246, Loss: 0.6616
# Epoch 247, Loss: 0.6582
# Epoch 248, Loss: 0.6549
# Epoch 249, Loss: 0.6514
# Epoch 250, Loss: 0.6483
# Epoch 251, Loss: 0.6446
# Epoch 252, Loss: 0.6416
# Epoch 253, Loss: 0.6381
# Epoch 254, Loss: 0.6348
# Epoch 255, Loss: 0.6316
# Epoch 256, Loss: 0.6284
# Epoch 257, Loss: 0.6253
# Epoch 258, Loss: 0.6223
# Epoch 259, Loss: 0.6183
# Epoch 260, Loss: 0.6154
# Epoch 261, Loss: 0.6122
# Epoch 262, Loss: 0.6088
# Epoch 263, Loss: 0.6057
# Epoch 264, Loss: 0.6028
# Epoch 265, Loss: 0.5995
# Epoch 266, Loss: 0.5960
# Epoch 267, Loss: 0.5933
# Epoch 268, Loss: 0.5901
# Epoch 269, Loss: 0.5871
# Epoch 270, Loss: 0.5841
# Epoch 271, Loss: 0.5809
# Epoch 272, Loss: 0.5779
# Epoch 273, Loss: 0.5747
# Epoch 274, Loss: 0.5719
# Epoch 275, Loss: 0.5689
# Epoch 276, Loss: 0.5658
# Epoch 277, Loss: 0.5627
# Epoch 278, Loss: 0.5597
# Epoch 279, Loss: 0.5568
# Epoch 280, Loss: 0.5538
# Epoch 281, Loss: 0.5506
# Epoch 282, Loss: 0.5479
# Epoch 283, Loss: 0.5449
# Epoch 284, Loss: 0.5418
# Epoch 285, Loss: 0.5391
# Epoch 286, Loss: 0.5361
# Epoch 287, Loss: 0.5335
# Epoch 288, Loss: 0.5307
# Epoch 289, Loss: 0.5277
# Epoch 290, Loss: 0.5248
# Epoch 291, Loss: 0.5219
# Epoch 292, Loss: 0.5192
# Epoch 293, Loss: 0.5164
# Epoch 294, Loss: 0.5133
# Epoch 295, Loss: 0.5107
# Epoch 296, Loss: 0.5080
# Epoch 297, Loss: 0.5056
# Epoch 298, Loss: 0.5025
# Epoch 299, Loss: 0.5002
# Epoch 300, Loss: 0.4972
#
# Training Time = 626.65065574646 seconds
# Final Training Loss = 0.49717244245529174
# Evaluation Accuracy = 0.4871

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import datasets, transforms
import time

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

data_path = "../data-unversioned/p1ch7"
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.4914, 0.4823, 0.4468),
                         (0.2470, 0.2435, 0.2616))
])

cifar10_train = datasets.CIFAR10(data_path, train=True, download=True, transform=transform)
cifar10_test  = datasets.CIFAR10(data_path, train=False, download=True, transform=transform)

cifar10_trainX = torch.stack([img.view(-1) for img, _ in cifar10_train])
cifar10_trainY = torch.tensor([label for _, label in cifar10_train], dtype=torch.long)

cifar10_testX = torch.stack([img.view(-1) for img, _ in cifar10_test])
cifar10_testY = torch.tensor([label for _, label in cifar10_test], dtype=torch.long)

cifar10_trainX = cifar10_trainX.to(device)
cifar10_trainY = cifar10_trainY.to(device)
cifar10_testX  = cifar10_testX.to(device)
cifar10_testY  = cifar10_testY.to(device)

train_dataset = torch.utils.data.TensorDataset(cifar10_trainX, cifar10_trainY)
val_dataset   = torch.utils.data.TensorDataset(cifar10_testX, cifar10_testY)

train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=64, shuffle=True)
val_loader   = torch.utils.data.DataLoader(val_dataset, batch_size=1000, shuffle=False)

# %%
input_size = 3 * 32 * 32
model = nn.Sequential(
    nn.Linear(input_size, 1024),
    nn.Tanh(),
    nn.Linear(1024, 512),
    nn.Tanh(),
    nn.Linear(512, 128),
    nn.Tanh(),
    nn.Linear(128, 10),
    nn.LogSoftmax(dim=1)
).to(device)

learning_rate = 1e-3
optimizer = optim.SGD(model.parameters(), lr=learning_rate)
loss_fn = nn.NLLLoss()

n_epochs = 300
start = time.time()

for epoch in range(n_epochs):
    model.train()
    running_loss = 0.0
    for batch_X, batch_Y in train_loader:
        outputs = model(batch_X)
        loss = loss_fn(outputs, batch_Y)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        running_loss += loss.item() * batch_X.size(0)

    epoch_loss = running_loss / len(train_loader.dataset)
    print(f"Epoch {epoch+1}, Loss: {epoch_loss:.4f}")

end = time.time()
print("\nTraining Time =", end - start, "seconds")
print("Final Training Loss =", epoch_loss)

model.eval()
correct = 0
total = 0
with torch.no_grad():
    for batch_X, batch_Y in val_loader:
        outputs = model(batch_X)
        preds = outputs.argmax(dim=1)
        correct += (preds == batch_Y).sum().item()
        total += batch_Y.size(0)

accuracy = correct / total
print("Evaluation Accuracy =", accuracy)
# Out:
# Epoch 1, Loss: 2.1704
# Epoch 2, Loss: 2.0347
# Epoch 3, Loss: 1.9674
# Epoch 4, Loss: 1.9233
# Epoch 5, Loss: 1.8910
# Epoch 6, Loss: 1.8657
# Epoch 7, Loss: 1.8448
# Epoch 8, Loss: 1.8268
# Epoch 9, Loss: 1.8109
# Epoch 10, Loss: 1.7967
# Epoch 11, Loss: 1.7836
# Epoch 12, Loss: 1.7717
# Epoch 13, Loss: 1.7604
# Epoch 14, Loss: 1.7499
# Epoch 15, Loss: 1.7401
# Epoch 16, Loss: 1.7307
# Epoch 17, Loss: 1.7219
# Epoch 18, Loss: 1.7137
# Epoch 19, Loss: 1.7057
# Epoch 20, Loss: 1.6980
# Epoch 21, Loss: 1.6909
# Epoch 22, Loss: 1.6838
# Epoch 23, Loss: 1.6771
# Epoch 24, Loss: 1.6706
# Epoch 25, Loss: 1.6642
# Epoch 26, Loss: 1.6582
# Epoch 27, Loss: 1.6520
# Epoch 28, Loss: 1.6462
# Epoch 29, Loss: 1.6403
# Epoch 30, Loss: 1.6347
# Epoch 31, Loss: 1.6290
# Epoch 32, Loss: 1.6235
# Epoch 33, Loss: 1.6181
# Epoch 34, Loss: 1.6127
# Epoch 35, Loss: 1.6073
# Epoch 36, Loss: 1.6020
# Epoch 37, Loss: 1.5965
# Epoch 38, Loss: 1.5912
# Epoch 39, Loss: 1.5857
# Epoch 40, Loss: 1.5807
# Epoch 41, Loss: 1.5753
# Epoch 42, Loss: 1.5698
# Epoch 43, Loss: 1.5645
# Epoch 44, Loss: 1.5592
# Epoch 45, Loss: 1.5536
# Epoch 46, Loss: 1.5482
# Epoch 47, Loss: 1.5429
# Epoch 48, Loss: 1.5373
# Epoch 49, Loss: 1.5313
# Epoch 50, Loss: 1.5257
# Epoch 51, Loss: 1.5202
# Epoch 52, Loss: 1.5145
# Epoch 53, Loss: 1.5083
# Epoch 54, Loss: 1.5024
# Epoch 55, Loss: 1.4965
# Epoch 56, Loss: 1.4905
# Epoch 57, Loss: 1.4841
# Epoch 58, Loss: 1.4777
# Epoch 59, Loss: 1.4717
# Epoch 60, Loss: 1.4654
# Epoch 61, Loss: 1.4590
# Epoch 62, Loss: 1.4522
# Epoch 63, Loss: 1.4457
# Epoch 64, Loss: 1.4392
# Epoch 65, Loss: 1.4325
# Epoch 66, Loss: 1.4254
# Epoch 67, Loss: 1.4190
# Epoch 68, Loss: 1.4120
# Epoch 69, Loss: 1.4046
# Epoch 70, Loss: 1.3981
# Epoch 71, Loss: 1.3906
# Epoch 72, Loss: 1.3834
# Epoch 73, Loss: 1.3763
# Epoch 74, Loss: 1.3688
# Epoch 75, Loss: 1.3615
# Epoch 76, Loss: 1.3539
# Epoch 77, Loss: 1.3463
# Epoch 78, Loss: 1.3385
# Epoch 79, Loss: 1.3306
# Epoch 80, Loss: 1.3226
# Epoch 81, Loss: 1.3147
# Epoch 82, Loss: 1.3070
# Epoch 83, Loss: 1.2985
# Epoch 84, Loss: 1.2895
# Epoch 85, Loss: 1.2815
# Epoch 86, Loss: 1.2732
# Epoch 87, Loss: 1.2640
# Epoch 88, Loss: 1.2553
# Epoch 89, Loss: 1.2467
# Epoch 90, Loss: 1.2372
# Epoch 91, Loss: 1.2281
# Epoch 92, Loss: 1.2187
# Epoch 93, Loss: 1.2097
# Epoch 94, Loss: 1.2002
# Epoch 95, Loss: 1.1905
# Epoch 96, Loss: 1.1813
# Epoch 97, Loss: 1.1712
# Epoch 98, Loss: 1.1609
# Epoch 99, Loss: 1.1512
# Epoch 100, Loss: 1.1414
# Epoch 101, Loss: 1.1313
# Epoch 102, Loss: 1.1209
# Epoch 103, Loss: 1.1101
# Epoch 104, Loss: 1.0997
# Epoch 105, Loss: 1.0891
# Epoch 106, Loss: 1.0787
# Epoch 107, Loss: 1.0684
# Epoch 108, Loss: 1.0576
# Epoch 109, Loss: 1.0473
# Epoch 110, Loss: 1.0350
# Epoch 111, Loss: 1.0243
# Epoch 112, Loss: 1.0132
# Epoch 113, Loss: 1.0025
# Epoch 114, Loss: 0.9907
# Epoch 115, Loss: 0.9804
# Epoch 116, Loss: 0.9693
# Epoch 117, Loss: 0.9577
# Epoch 118, Loss: 0.9462
# Epoch 119, Loss: 0.9346
# Epoch 120, Loss: 0.9233
# Epoch 121, Loss: 0.9126
# Epoch 122, Loss: 0.9007
# Epoch 123, Loss: 0.8900
# Epoch 124, Loss: 0.8785
# Epoch 125, Loss: 0.8675
# Epoch 126, Loss: 0.8550
# Epoch 127, Loss: 0.8437
# Epoch 128, Loss: 0.8310
# Epoch 129, Loss: 0.8206
# Epoch 130, Loss: 0.8098
# Epoch 131, Loss: 0.7975
# Epoch 132, Loss: 0.7867
# Epoch 133, Loss: 0.7745
# Epoch 134, Loss: 0.7637
# Epoch 135, Loss: 0.7523
# Epoch 136, Loss: 0.7400
# Epoch 137, Loss: 0.7287
# Epoch 138, Loss: 0.7166
# Epoch 139, Loss: 0.7064
# Epoch 140, Loss: 0.6938
# Epoch 141, Loss: 0.6824
# Epoch 142, Loss: 0.6720
# Epoch 143, Loss: 0.6605
# Epoch 144, Loss: 0.6491
# Epoch 145, Loss: 0.6388
# Epoch 146, Loss: 0.6299
# Epoch 147, Loss: 0.6167
# Epoch 148, Loss: 0.6074
# Epoch 149, Loss: 0.5945
# Epoch 150, Loss: 0.5850
# Epoch 151, Loss: 0.5754
# Epoch 152, Loss: 0.5650
# Epoch 153, Loss: 0.5545
# Epoch 154, Loss: 0.5418
# Epoch 155, Loss: 0.5319
# Epoch 156, Loss: 0.5222
# Epoch 157, Loss: 0.5113
# Epoch 158, Loss: 0.5011
# Epoch 159, Loss: 0.4915
# Epoch 160, Loss: 0.4811
# Epoch 161, Loss: 0.4714
# Epoch 162, Loss: 0.4626
# Epoch 163, Loss: 0.4512
# Epoch 164, Loss: 0.4440
# Epoch 165, Loss: 0.4351
# Epoch 166, Loss: 0.4236
# Epoch 167, Loss: 0.4172
# Epoch 168, Loss: 0.4038
# Epoch 169, Loss: 0.3966
# Epoch 170, Loss: 0.3885
# Epoch 171, Loss: 0.3781
# Epoch 172, Loss: 0.3689
# Epoch 173, Loss: 0.3596
# Epoch 174, Loss: 0.3523
# Epoch 175, Loss: 0.3453
# Epoch 176, Loss: 0.3350
# Epoch 177, Loss: 0.3287
# Epoch 178, Loss: 0.3261
# Epoch 179, Loss: 0.3098
# Epoch 180, Loss: 0.3026
# Epoch 181, Loss: 0.2957
# Epoch 182, Loss: 0.2905
# Epoch 183, Loss: 0.2803
# Epoch 184, Loss: 0.2723
# Epoch 185, Loss: 0.2652
# Epoch 186, Loss: 0.2594
# Epoch 187, Loss: 0.2521
# Epoch 188, Loss: 0.2443
# Epoch 189, Loss: 0.2407
# Epoch 190, Loss: 0.2341
# Epoch 191, Loss: 0.2289
# Epoch 192, Loss: 0.2181
# Epoch 193, Loss: 0.2123
# Epoch 194, Loss: 0.2072
# Epoch 195, Loss: 0.1994
# Epoch 196, Loss: 0.1933
# Epoch 197, Loss: 0.1887
# Epoch 198, Loss: 0.1818
# Epoch 199, Loss: 0.1769
# Epoch 200, Loss: 0.1729
# Epoch 201, Loss: 0.1715
# Epoch 202, Loss: 0.1633
# Epoch 203, Loss: 0.1562
# Epoch 204, Loss: 0.1551
# Epoch 205, Loss: 0.1456
# Epoch 206, Loss: 0.1409
# Epoch 207, Loss: 0.1392
# Epoch 208, Loss: 0.1444
# Epoch 209, Loss: 0.1301
# Epoch 210, Loss: 0.1280
# Epoch 211, Loss: 0.1212
# Epoch 212, Loss: 0.1206
# Epoch 213, Loss: 0.1142
# Epoch 214, Loss: 0.1107
# Epoch 215, Loss: 0.1055
# Epoch 216, Loss: 0.1101
# Epoch 217, Loss: 0.1122
# Epoch 218, Loss: 0.0962
# Epoch 219, Loss: 0.0983
# Epoch 220, Loss: 0.0899
# Epoch 221, Loss: 0.0902
# Epoch 222, Loss: 0.0864
# Epoch 223, Loss: 0.0889
# Epoch 224, Loss: 0.0797
# Epoch 225, Loss: 0.0784
# Epoch 226, Loss: 0.0775
# Epoch 227, Loss: 0.0726
# Epoch 228, Loss: 0.0717
# Epoch 229, Loss: 0.0694
# Epoch 230, Loss: 0.0672
# Epoch 231, Loss: 0.0703
# Epoch 232, Loss: 0.0750
# Epoch 233, Loss: 0.0631
# Epoch 234, Loss: 0.0737
# Epoch 235, Loss: 0.0582
# Epoch 236, Loss: 0.0567
# Epoch 237, Loss: 0.0600
# Epoch 238, Loss: 0.0521
# Epoch 239, Loss: 0.0505
# Epoch 240, Loss: 0.0495
# Epoch 241, Loss: 0.0483
# Epoch 242, Loss: 0.0484
# Epoch 243, Loss: 0.0556
# Epoch 244, Loss: 0.0451
# Epoch 245, Loss: 0.0457
# Epoch 246, Loss: 0.0419
# Epoch 247, Loss: 0.0418
# Epoch 248, Loss: 0.0399
# Epoch 249, Loss: 0.0392
# Epoch 250, Loss: 0.0376
# Epoch 251, Loss: 0.0374
# Epoch 252, Loss: 0.0361
# Epoch 253, Loss: 0.0351
# Epoch 254, Loss: 0.0347
# Epoch 255, Loss: 0.0337
# Epoch 256, Loss: 0.0330
# Epoch 257, Loss: 0.0323
# Epoch 258, Loss: 0.0316
# Epoch 259, Loss: 0.0309
# Epoch 260, Loss: 0.0297
# Epoch 261, Loss: 0.0299
# Epoch 262, Loss: 0.0428
# Epoch 263, Loss: 0.0286
# Epoch 264, Loss: 0.0278
# Epoch 265, Loss: 0.0271
# Epoch 266, Loss: 0.0265
# Epoch 267, Loss: 0.0263
# Epoch 268, Loss: 0.0256
# Epoch 269, Loss: 0.0250
# Epoch 270, Loss: 0.0247
# Epoch 271, Loss: 0.0248
# Epoch 272, Loss: 0.0238
# Epoch 273, Loss: 0.0232
# Epoch 274, Loss: 0.0231
# Epoch 275, Loss: 0.0222
# Epoch 276, Loss: 0.0221
# Epoch 277, Loss: 0.0216
# Epoch 278, Loss: 0.0211
# Epoch 279, Loss: 0.0208
# Epoch 280, Loss: 0.0204
# Epoch 281, Loss: 0.0202
# Epoch 282, Loss: 0.0199
# Epoch 283, Loss: 0.0194
# Epoch 284, Loss: 0.0192
# Epoch 285, Loss: 0.0188
# Epoch 286, Loss: 0.0185
# Epoch 287, Loss: 0.0182
# Epoch 288, Loss: 0.0179
# Epoch 289, Loss: 0.0177
# Epoch 290, Loss: 0.0176
# Epoch 291, Loss: 0.0173
# Epoch 292, Loss: 0.0169
# Epoch 293, Loss: 0.0166
# Epoch 294, Loss: 0.0164
# Epoch 295, Loss: 0.0162
# Epoch 296, Loss: 0.0160
# Epoch 297, Loss: 0.0157
# Epoch 298, Loss: 0.0155
# Epoch 299, Loss: 0.0153
# Epoch 300, Loss: 0.0151
#
# Training Time = 1167.7478566169739 seconds
# Final Training Loss = 0.015094490163475275
# Evaluation Accuracy = 0.4552

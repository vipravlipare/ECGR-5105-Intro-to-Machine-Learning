# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import datasets, transforms
import time

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)

data_path = "../data-unversioned/p1ch7"

transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.4914, 0.4823, 0.4468),
                         (0.2470, 0.2435, 0.2616))
])

cifar10_train = datasets.CIFAR10(data_path, train=True, download=True, transform=transform)
cifar10_test  = datasets.CIFAR10(data_path, train=False, download=True, transform=transform)

trainX = torch.stack([img for img, _ in cifar10_train]).to(device)
trainY = torch.tensor([label for _, label in cifar10_train], dtype=torch.long).to(device)

testX = torch.stack([img for img, _ in cifar10_test]).to(device)
testY = torch.tensor([label for _, label in cifar10_test], dtype=torch.long).to(device)

train_dataset = torch.utils.data.TensorDataset(trainX, trainY)
val_dataset   = torch.utils.data.TensorDataset(testX, testY)

train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=64, shuffle=True)
val_loader   = torch.utils.data.DataLoader(val_dataset, batch_size=1000, shuffle=False)
# Out:
# Using device: cuda

# %%
class Net(nn.Module):
    def __init__(self):
        super().__init__()

        self.conv1 = nn.Conv2d(3, 16, kernel_size=3, padding=1)
        self.act1  = nn.Tanh()
        self.pool1 = nn.MaxPool2d(2)

        self.conv2 = nn.Conv2d(16, 32, kernel_size=3, padding=1)
        self.act2  = nn.Tanh()
        self.pool2 = nn.MaxPool2d(2)

        self.fc1 = nn.Linear(32 * 8 * 8, 64)
        self.act3 = nn.Tanh()

        self.fc2 = nn.Linear(64, 10)

    def forward(self, x):
        x = self.pool1(self.act1(self.conv1(x)))
        x = self.pool2(self.act2(self.conv2(x)))
        x = x.view(x.size(0), -1)
        x = self.act3(self.fc1(x))
        x = self.fc2(x)
        return x

model = Net().to(device)

# %%
loss_fn = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=1e-3)

n_epochs = 300
start = time.time()

for epoch in range(n_epochs):
    model.train()
    running_loss = 0.0

    for batch_X, batch_Y in train_loader:
        optimizer.zero_grad()
        outputs = model(batch_X)
        loss = loss_fn(outputs, batch_Y)
        loss.backward()
        optimizer.step()

        running_loss += loss.item() * batch_X.size(0)

    epoch_loss = running_loss / len(train_loader.dataset)
    print(f"Epoch {epoch+1}, Loss: {epoch_loss:.4f}")

end = time.time()

print("\nTraining Time =", end - start, "seconds")
print("Final Training Loss =", epoch_loss)

model.eval()
correct = 0
total = 0

with torch.no_grad():
    for batch_X, batch_Y in val_loader:
        outputs = model(batch_X)
        preds = outputs.argmax(dim=1)
        correct += (preds == batch_Y).sum().item()
        total += batch_Y.size(0)

accuracy = correct / total
print("Evaluation Accuracy =", accuracy)
# Out:
# Epoch 1, Loss: 2.2468
# Epoch 2, Loss: 2.1241
# Epoch 3, Loss: 2.0291
# Epoch 4, Loss: 1.9592
# Epoch 5, Loss: 1.9086
# Epoch 6, Loss: 1.8671
# Epoch 7, Loss: 1.8284
# Epoch 8, Loss: 1.7915
# Epoch 9, Loss: 1.7574
# Epoch 10, Loss: 1.7269
# Epoch 11, Loss: 1.7000
# Epoch 12, Loss: 1.6758
# Epoch 13, Loss: 1.6537
# Epoch 14, Loss: 1.6332
# Epoch 15, Loss: 1.6139
# Epoch 16, Loss: 1.5956
# Epoch 17, Loss: 1.5782
# Epoch 18, Loss: 1.5617
# Epoch 19, Loss: 1.5459
# Epoch 20, Loss: 1.5308
# Epoch 21, Loss: 1.5166
# Epoch 22, Loss: 1.5030
# Epoch 23, Loss: 1.4902
# Epoch 24, Loss: 1.4780
# Epoch 25, Loss: 1.4665
# Epoch 26, Loss: 1.4556
# Epoch 27, Loss: 1.4452
# Epoch 28, Loss: 1.4351
# Epoch 29, Loss: 1.4253
# Epoch 30, Loss: 1.4162
# Epoch 31, Loss: 1.4071
# Epoch 32, Loss: 1.3980
# Epoch 33, Loss: 1.3893
# Epoch 34, Loss: 1.3805
# Epoch 35, Loss: 1.3719
# Epoch 36, Loss: 1.3633
# Epoch 37, Loss: 1.3548
# Epoch 38, Loss: 1.3460
# Epoch 39, Loss: 1.3375
# Epoch 40, Loss: 1.3290
# Epoch 41, Loss: 1.3206
# Epoch 42, Loss: 1.3120
# Epoch 43, Loss: 1.3034
# Epoch 44, Loss: 1.2949
# Epoch 45, Loss: 1.2865
# Epoch 46, Loss: 1.2782
# Epoch 47, Loss: 1.2699
# Epoch 48, Loss: 1.2615
# Epoch 49, Loss: 1.2533
# Epoch 50, Loss: 1.2455
# Epoch 51, Loss: 1.2375
# Epoch 52, Loss: 1.2297
# Epoch 53, Loss: 1.2221
# Epoch 54, Loss: 1.2144
# Epoch 55, Loss: 1.2070
# Epoch 56, Loss: 1.1998
# Epoch 57, Loss: 1.1927
# Epoch 58, Loss: 1.1858
# Epoch 59, Loss: 1.1786
# Epoch 60, Loss: 1.1719
# Epoch 61, Loss: 1.1653
# Epoch 62, Loss: 1.1587
# Epoch 63, Loss: 1.1523
# Epoch 64, Loss: 1.1460
# Epoch 65, Loss: 1.1398
# Epoch 66, Loss: 1.1336
# Epoch 67, Loss: 1.1277
# Epoch 68, Loss: 1.1217
# Epoch 69, Loss: 1.1158
# Epoch 70, Loss: 1.1099
# Epoch 71, Loss: 1.1044
# Epoch 72, Loss: 1.0985
# Epoch 73, Loss: 1.0928
# Epoch 74, Loss: 1.0877
# Epoch 75, Loss: 1.0822
# Epoch 76, Loss: 1.0767
# Epoch 77, Loss: 1.0714
# Epoch 78, Loss: 1.0659
# Epoch 79, Loss: 1.0608
# Epoch 80, Loss: 1.0558
# Epoch 81, Loss: 1.0506
# Epoch 82, Loss: 1.0459
# Epoch 83, Loss: 1.0406
# Epoch 84, Loss: 1.0360
# Epoch 85, Loss: 1.0311
# Epoch 86, Loss: 1.0260
# Epoch 87, Loss: 1.0215
# Epoch 88, Loss: 1.0169
# Epoch 89, Loss: 1.0122
# Epoch 90, Loss: 1.0078
# Epoch 91, Loss: 1.0034
# Epoch 92, Loss: 0.9988
# Epoch 93, Loss: 0.9944
# Epoch 94, Loss: 0.9901
# Epoch 95, Loss: 0.9860
# Epoch 96, Loss: 0.9815
# Epoch 97, Loss: 0.9774
# Epoch 98, Loss: 0.9733
# Epoch 99, Loss: 0.9693
# Epoch 100, Loss: 0.9651
# Epoch 101, Loss: 0.9614
# Epoch 102, Loss: 0.9571
# Epoch 103, Loss: 0.9534
# Epoch 104, Loss: 0.9495
# Epoch 105, Loss: 0.9458
# Epoch 106, Loss: 0.9419
# Epoch 107, Loss: 0.9380
# Epoch 108, Loss: 0.9344
# Epoch 109, Loss: 0.9310
# Epoch 110, Loss: 0.9273
# Epoch 111, Loss: 0.9237
# Epoch 112, Loss: 0.9203
# Epoch 113, Loss: 0.9167
# Epoch 114, Loss: 0.9137
# Epoch 115, Loss: 0.9101
# Epoch 116, Loss: 0.9069
# Epoch 117, Loss: 0.9035
# Epoch 118, Loss: 0.9000
# Epoch 119, Loss: 0.8968
# Epoch 120, Loss: 0.8938
# Epoch 121, Loss: 0.8907
# Epoch 122, Loss: 0.8874
# Epoch 123, Loss: 0.8843
# Epoch 124, Loss: 0.8811
# Epoch 125, Loss: 0.8786
# Epoch 126, Loss: 0.8753
# Epoch 127, Loss: 0.8725
# Epoch 128, Loss: 0.8695
# Epoch 129, Loss: 0.8666
# Epoch 130, Loss: 0.8637
# Epoch 131, Loss: 0.8608
# Epoch 132, Loss: 0.8579
# Epoch 133, Loss: 0.8551
# Epoch 134, Loss: 0.8522
# Epoch 135, Loss: 0.8498
# Epoch 136, Loss: 0.8471
# Epoch 137, Loss: 0.8444
# Epoch 138, Loss: 0.8418
# Epoch 139, Loss: 0.8391
# Epoch 140, Loss: 0.8365
# Epoch 141, Loss: 0.8344
# Epoch 228, Loss: 0.6642
# Epoch 229, Loss: 0.6628
# Epoch 230, Loss: 0.6608
# Epoch 231, Loss: 0.6594
# Epoch 232, Loss: 0.6580
# Epoch 233, Loss: 0.6562
# Epoch 234, Loss: 0.6547
# Epoch 235, Loss: 0.6535
# Epoch 236, Loss: 0.6514
# Epoch 237, Loss: 0.6500
# Epoch 238, Loss: 0.6484
# Epoch 239, Loss: 0.6470
# Epoch 240, Loss: 0.6457
# Epoch 241, Loss: 0.6439
# Epoch 242, Loss: 0.6425
# Epoch 243, Loss: 0.6408
# Epoch 244, Loss: 0.6393
# Epoch 245, Loss: 0.6378
# Epoch 246, Loss: 0.6362
# Epoch 247, Loss: 0.6348
# Epoch 248, Loss: 0.6333
# Epoch 249, Loss: 0.6320
# Epoch 250, Loss: 0.6303
# Epoch 251, Loss: 0.6286
# Epoch 252, Loss: 0.6270
# Epoch 253, Loss: 0.6259
# Epoch 254, Loss: 0.6243
# Epoch 255, Loss: 0.6227
# Epoch 256, Loss: 0.6214
# Epoch 257, Loss: 0.6197
# Epoch 258, Loss: 0.6183
# Epoch 259, Loss: 0.6167
# Epoch 260, Loss: 0.6152
# Epoch 261, Loss: 0.6138
# Epoch 262, Loss: 0.6124
# Epoch 263, Loss: 0.6111
# Epoch 264, Loss: 0.6093
# Epoch 265, Loss: 0.6082
# Epoch 266, Loss: 0.6066
# Epoch 267, Loss: 0.6052
# Epoch 268, Loss: 0.6040
# Epoch 269, Loss: 0.6024
# Epoch 270, Loss: 0.6008
# Epoch 271, Loss: 0.5997
# Epoch 272, Loss: 0.5979
# Epoch 273, Loss: 0.5966
# Epoch 274, Loss: 0.5952
# Epoch 275, Loss: 0.5939
# Epoch 276, Loss: 0.5924
# Epoch 277, Loss: 0.5906
# Epoch 278, Loss: 0.5898
# Epoch 279, Loss: 0.5880
# Epoch 280, Loss: 0.5869
# Epoch 281, Loss: 0.5854
# Epoch 282, Loss: 0.5839
# Epoch 283, Loss: 0.5827
# Epoch 284, Loss: 0.5810
# Epoch 285, Loss: 0.5800
# Epoch 286, Loss: 0.5783
# Epoch 287, Loss: 0.5770
# Epoch 288, Loss: 0.5757
# Epoch 289, Loss: 0.5742
# Epoch 290, Loss: 0.5731
# Epoch 291, Loss: 0.5716
# Epoch 292, Loss: 0.5702
# Epoch 293, Loss: 0.5686
# Epoch 294, Loss: 0.5672
# Epoch 295, Loss: 0.5661
# Epoch 296, Loss: 0.5645
# Epoch 297, Loss: 0.5636
# Epoch 298, Loss: 0.5617
# Epoch 299, Loss: 0.5604
# Epoch 300, Loss: 0.5593
#
# Training Time = 1710.6581213474274 seconds
# Final Training Loss = 0.5592639330291748
# Evaluation Accuracy = 0.7074

# %%
# Homework 6-3A FNN Results
print("Homework 6-3A - FNN Results")
print("Training Time = 626.65065574646 seconds")
print("Final Training Loss = 0.49717244245529174")
print("Evaluation Accuracy = 0.4871")
# Out:
# Homework 6-3A - FNN Results
# Training Time = 626.65065574646 seconds
# Final Training Loss = 0.49717244245529174
# Evaluation Accuracy = 0.4871

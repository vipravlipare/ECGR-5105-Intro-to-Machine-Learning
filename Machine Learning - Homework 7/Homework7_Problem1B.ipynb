# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import datasets, transforms
import time

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)

data_path = "../data-unversioned/p1ch7"

transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.4914, 0.4823, 0.4468),
                         (0.2470, 0.2435, 0.2616))
])

cifar10_train = datasets.CIFAR10(data_path, train=True, download=True, transform=transform)
cifar10_test  = datasets.CIFAR10(data_path, train=False, download=True, transform=transform)

trainX = torch.stack([img for img, _ in cifar10_train]).to(device)
trainY = torch.tensor([label for _, label in cifar10_train], dtype=torch.long).to(device)

testX = torch.stack([img for img, _ in cifar10_test]).to(device)
testY = torch.tensor([label for _, label in cifar10_test], dtype=torch.long).to(device)

train_dataset = torch.utils.data.TensorDataset(trainX, trainY)
val_dataset   = torch.utils.data.TensorDataset(testX, testY)

train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=64, shuffle=True)
val_loader   = torch.utils.data.DataLoader(val_dataset, batch_size=1000, shuffle=False)
# Out:
# Using device: cuda

# %%
class Net(nn.Module):
    def __init__(self):
        super().__init__()
        self.conv1 = nn.Conv2d(3, 16, kernel_size=3, padding=1)
        self.act1  = nn.Tanh()
        self.pool1 = nn.MaxPool2d(2)

        self.conv2 = nn.Conv2d(16, 32, kernel_size=3, padding=1)
        self.act2  = nn.Tanh()
        self.pool2 = nn.MaxPool2d(2)

        self.conv3 = nn.Conv2d(32, 64, kernel_size=3, padding=1)
        self.act3  = nn.Tanh()
        self.pool3 = nn.MaxPool2d(2)

        self.fc1 = nn.Linear(64 * 4 * 4, 64)
        self.act4 = nn.Tanh()
        self.fc2 = nn.Linear(64, 10)

    def forward(self, x):
        x = self.pool1(self.act1(self.conv1(x)))
        x = self.pool2(self.act2(self.conv2(x)))
        x = self.pool3(self.act3(self.conv3(x)))

        x = x.view(x.size(0), -1)

        x = self.act4(self.fc1(x))
        x = self.fc2(x)

        return x
model = Net().to(device)

# %%
loss_fn = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=1e-3)

n_epochs = 300
start = time.time()

for epoch in range(n_epochs):
    model.train()
    running_loss = 0.0

    for batch_X, batch_Y in train_loader:
        optimizer.zero_grad()
        outputs = model(batch_X)
        loss = loss_fn(outputs, batch_Y)
        loss.backward()
        optimizer.step()

        running_loss += loss.item() * batch_X.size(0)

    epoch_loss = running_loss / len(train_loader.dataset)
    print(f"Epoch {epoch+1}, Loss: {epoch_loss:.4f}")

end = time.time()

print("\nTraining Time =", end - start, "seconds")
print("Final Training Loss =", epoch_loss)

model.eval()
correct = 0
total = 0

with torch.no_grad():
    for batch_X, batch_Y in val_loader:
        outputs = model(batch_X)
        preds = outputs.argmax(dim=1)
        correct += (preds == batch_Y).sum().item()
        total += batch_Y.size(0)

accuracy = correct / total
print("Evaluation Accuracy =", accuracy)
# Out:
# Epoch 1, Loss: 2.2788
# Epoch 2, Loss: 2.2163
# Epoch 3, Loss: 2.1241
# Epoch 4, Loss: 2.0483
# Epoch 5, Loss: 1.9976
# Epoch 6, Loss: 1.9641
# Epoch 7, Loss: 1.9383
# Epoch 8, Loss: 1.9157
# Epoch 9, Loss: 1.8943
# Epoch 10, Loss: 1.8734
# Epoch 11, Loss: 1.8523
# Epoch 12, Loss: 1.8305
# Epoch 13, Loss: 1.8071
# Epoch 14, Loss: 1.7813
# Epoch 15, Loss: 1.7528
# Epoch 16, Loss: 1.7229
# Epoch 17, Loss: 1.6941
# Epoch 18, Loss: 1.6680
# Epoch 19, Loss: 1.6452
# Epoch 20, Loss: 1.6251
# Epoch 21, Loss: 1.6075
# Epoch 22, Loss: 1.5916
# Epoch 23, Loss: 1.5769
# Epoch 24, Loss: 1.5632
# Epoch 25, Loss: 1.5502
# Epoch 26, Loss: 1.5378
# Epoch 27, Loss: 1.5258
# Epoch 28, Loss: 1.5141
# Epoch 29, Loss: 1.5029
# Epoch 30, Loss: 1.4920
# Epoch 31, Loss: 1.4812
# Epoch 32, Loss: 1.4708
# Epoch 33, Loss: 1.4605
# Epoch 34, Loss: 1.4503
# Epoch 35, Loss: 1.4401
# Epoch 36, Loss: 1.4301
# Epoch 37, Loss: 1.4197
# Epoch 38, Loss: 1.4097
# Epoch 39, Loss: 1.3994
# Epoch 40, Loss: 1.3895
# Epoch 41, Loss: 1.3794
# Epoch 42, Loss: 1.3699
# Epoch 43, Loss: 1.3604
# Epoch 44, Loss: 1.3516
# Epoch 45, Loss: 1.3426
# Epoch 46, Loss: 1.3340
# Epoch 47, Loss: 1.3257
# Epoch 48, Loss: 1.3176
# Epoch 49, Loss: 1.3100
# Epoch 50, Loss: 1.3022
# Epoch 51, Loss: 1.2946
# Epoch 52, Loss: 1.2872
# Epoch 53, Loss: 1.2799
# Epoch 54, Loss: 1.2730
# Epoch 55, Loss: 1.2659
# Epoch 56, Loss: 1.2589
# Epoch 57, Loss: 1.2523
# Epoch 58, Loss: 1.2452
# Epoch 59, Loss: 1.2389
# Epoch 60, Loss: 1.2322
# Epoch 61, Loss: 1.2256
# Epoch 62, Loss: 1.2195
# Epoch 63, Loss: 1.2132
# Epoch 64, Loss: 1.2070
# Epoch 65, Loss: 1.2010
# Epoch 66, Loss: 1.1949
# Epoch 67, Loss: 1.1887
# Epoch 68, Loss: 1.1830
# Epoch 69, Loss: 1.1773
# Epoch 70, Loss: 1.1714
# Epoch 71, Loss: 1.1658
# Epoch 72, Loss: 1.1598
# Epoch 73, Loss: 1.1542
# Epoch 74, Loss: 1.1489
# Epoch 75, Loss: 1.1437
# Epoch 76, Loss: 1.1381
# Epoch 77, Loss: 1.1326
# Epoch 78, Loss: 1.1272
# Epoch 79, Loss: 1.1219
# Epoch 80, Loss: 1.1165
# Epoch 81, Loss: 1.1112
# Epoch 82, Loss: 1.1060
# Epoch 83, Loss: 1.1010
# Epoch 84, Loss: 1.0958
# Epoch 85, Loss: 1.0908
# Epoch 86, Loss: 1.0855
# Epoch 87, Loss: 1.0805
# Epoch 88, Loss: 1.0756
# Epoch 89, Loss: 1.0706
# Epoch 90, Loss: 1.0656
# Epoch 91, Loss: 1.0606
# Epoch 92, Loss: 1.0559
# Epoch 93, Loss: 1.0509
# Epoch 94, Loss: 1.0461
# Epoch 95, Loss: 1.0413
# Epoch 96, Loss: 1.0364
# Epoch 97, Loss: 1.0317
# Epoch 98, Loss: 1.0268
# Epoch 99, Loss: 1.0222
# Epoch 100, Loss: 1.0176
# Epoch 101, Loss: 1.0131
# Epoch 102, Loss: 1.0083
# Epoch 103, Loss: 1.0038
# Epoch 104, Loss: 0.9991
# Epoch 105, Loss: 0.9947
# Epoch 106, Loss: 0.9906
# Epoch 107, Loss: 0.9859
# Epoch 108, Loss: 0.9815
# Epoch 109, Loss: 0.9771
# Epoch 110, Loss: 0.9727
# Epoch 111, Loss: 0.9686
# Epoch 112, Loss: 0.9642
# Epoch 113, Loss: 0.9600
# Epoch 114, Loss: 0.9561
# Epoch 115, Loss: 0.9522
# Epoch 116, Loss: 0.9480
# Epoch 117, Loss: 0.9442
# Epoch 118, Loss: 0.9400
# Epoch 119, Loss: 0.9360
# Epoch 120, Loss: 0.9325
# Epoch 121, Loss: 0.9285
# Epoch 122, Loss: 0.9247
# Epoch 123, Loss: 0.9209
# Epoch 124, Loss: 0.9171
# Epoch 125, Loss: 0.9135
# Epoch 126, Loss: 0.9098
# Epoch 127, Loss: 0.9065
# Epoch 128, Loss: 0.9030
# Epoch 129, Loss: 0.8996
# Epoch 130, Loss: 0.8963
# Epoch 131, Loss: 0.8925
# Epoch 132, Loss: 0.8894
# Epoch 133, Loss: 0.8857
# Epoch 134, Loss: 0.8828
# Epoch 135, Loss: 0.8794
# Epoch 136, Loss: 0.8761
# Epoch 225, Loss: 0.6783
# Epoch 226, Loss: 0.6763
# Epoch 227, Loss: 0.6748
# Epoch 228, Loss: 0.6731
# Epoch 229, Loss: 0.6716
# Epoch 230, Loss: 0.6699
# Epoch 231, Loss: 0.6682
# Epoch 232, Loss: 0.6665
# Epoch 233, Loss: 0.6649
# Epoch 234, Loss: 0.6634
# Epoch 235, Loss: 0.6615
# Epoch 236, Loss: 0.6597
# Epoch 237, Loss: 0.6581
# Epoch 238, Loss: 0.6565
# Epoch 239, Loss: 0.6555
# Epoch 240, Loss: 0.6535
# Epoch 241, Loss: 0.6520
# Epoch 242, Loss: 0.6508
# Epoch 243, Loss: 0.6488
# Epoch 244, Loss: 0.6472
# Epoch 245, Loss: 0.6456
# Epoch 246, Loss: 0.6438
# Epoch 247, Loss: 0.6430
# Epoch 248, Loss: 0.6414
# Epoch 249, Loss: 0.6395
# Epoch 250, Loss: 0.6382
# Epoch 251, Loss: 0.6365
# Epoch 252, Loss: 0.6348
# Epoch 253, Loss: 0.6336
# Epoch 254, Loss: 0.6319
# Epoch 255, Loss: 0.6305
# Epoch 256, Loss: 0.6292
# Epoch 257, Loss: 0.6273
# Epoch 258, Loss: 0.6260
# Epoch 259, Loss: 0.6245
# Epoch 260, Loss: 0.6228
# Epoch 261, Loss: 0.6214
# Epoch 262, Loss: 0.6201
# Epoch 263, Loss: 0.6185
# Epoch 264, Loss: 0.6169
# Epoch 265, Loss: 0.6158
# Epoch 266, Loss: 0.6141
# Epoch 267, Loss: 0.6130
# Epoch 268, Loss: 0.6111
# Epoch 269, Loss: 0.6101
# Epoch 270, Loss: 0.6084
# Epoch 271, Loss: 0.6070
# Epoch 272, Loss: 0.6054
# Epoch 273, Loss: 0.6040
# Epoch 274, Loss: 0.6030
# Epoch 275, Loss: 0.6014
# Epoch 276, Loss: 0.6004
# Epoch 277, Loss: 0.5984
# Epoch 278, Loss: 0.5974
# Epoch 279, Loss: 0.5956
# Epoch 280, Loss: 0.5940
# Epoch 281, Loss: 0.5929
# Epoch 282, Loss: 0.5914
# Epoch 283, Loss: 0.5900
# Epoch 284, Loss: 0.5890
# Epoch 285, Loss: 0.5875
# Epoch 286, Loss: 0.5861
# Epoch 287, Loss: 0.5844
# Epoch 288, Loss: 0.5834
# Epoch 289, Loss: 0.5821
# Epoch 290, Loss: 0.5808
# Epoch 291, Loss: 0.5792
# Epoch 292, Loss: 0.5781
# Epoch 293, Loss: 0.5766
# Epoch 294, Loss: 0.5750
# Epoch 295, Loss: 0.5740
# Epoch 296, Loss: 0.5728
# Epoch 297, Loss: 0.5711
# Epoch 298, Loss: 0.5698
# Epoch 299, Loss: 0.5687
# Epoch 300, Loss: 0.5673
#
# Training Time = 1944.0796592235565 seconds
# Final Training Loss = 0.5673410249710082
# Evaluation Accuracy = 0.7333

# %%
# Homework 6-3B FNN Results
print("Homework 6-3B - FNN Results")
print("Training Time = 1167.7478566169739 seconds")
print("Final Training Loss = 0.015094490163475275")
print("Evaluation Accuracy = 0.4552")
# Out:
# Homework 6-3B - FNN Results
# Training Time = 1167.7478566169739 seconds
# Final Training Loss = 0.015094490163475275
# Evaluation Accuracy = 0.4552
